# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

def mse(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.square(np.subtract(actual,pred)).mean()

# %%
u_th = []
v_th = []
p_th = []
x_th = []
y_th = []

i = 0
with open('v_velocity_y=0.5.csv') as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        # print(line)
        if (i!=0):
            x_th.append(float(line[1]))
            u_th.append(float(line[2]))
        i+= 1

plt.plot(x_th, u_th, label = r'Résultats de Ghia et al. (Référence)')

u = []
v = []
p = []
x = []
y = []

i = 0
with open('y05_Jacobi.csv') as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        # print(line)
        if (i!=0):
            x.append(float(line[6]))
            y.append(float(line[7]))
            u.append(float(line[2]))
            v.append(float(line[3]))
            p.append(float(line[1]))
        i+= 1

plt.plot(x, v, label = r'Méthode de Jacobi')


u = []
v = []
p = []
x = []
y = []

i = 0
with open('y05_Gauss.csv') as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        # print(line)
        if (i!=0):
            x.append(float(line[6]))
            y.append(float(line[7]))
            u.append(float(line[2]))
            v.append(float(line[3]))
            p.append(float(line[1]))
        i+= 1

plt.plot(x, v, label = r'Méthode de Gauss-Seidel')

u = []
v = []
p = []
x = []
y = []

i = 0
with open('y05_Surrelaxation.csv') as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        # print(line)
        if (i!=0):
            x.append(float(line[6]))
            y.append(float(line[7]))
            u.append(float(line[2]))
            v.append(float(line[3]))
            p.append(float(line[1]))
        i+= 1

plt.plot(x, v, label = r'Méthode de Surrelaxation')

u = []
v = []
p = []
x = []
y = []

i = 0
with open('y05_CG.csv') as file:
    reader = csv.reader(file, delimiter=',')
    for line in reader:
        # print(line)
        if (i!=0):
            x.append(float(line[6]))
            y.append(float(line[7]))
            u.append(float(line[2]))
            v.append(float(line[3]))
            p.append(float(line[1]))
        i+= 1

plt.plot(x, v, label = r'Méthode du Gradient Conjugué')


plt.xlabel(r'$x$ $[m]$')
plt.ylabel(r'$v$ $[m.s^{-1}]$')
plt.legend()
#plt.text(0.5, 1, 'mean square error = %5.3e' % mse(u, u_th) )
plt.savefig('v_y05_linearSolving.png', dpi=300)
plt.show()
